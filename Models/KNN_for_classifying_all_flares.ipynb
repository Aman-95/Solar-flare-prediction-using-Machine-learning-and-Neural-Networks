# %% [markdown]
# #**Classifying all x-ray class flares using KNN**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_excel("Dataset_set_2_for_classification.xlsx")

# %%
dataset
# Out:
#         1      2     3           4            5   ... 51 52 53 54           55
# 0     YEAR  MONTH  DATE  RADIO FLUX  SUN SPOT NO  ...  1  2  3  4  x-ray class
# 1     1997      6     2          77           35  ...  0  0  0  0            0
# 2     1997      6     3          75           20  ...  0  0  0  0            0
# 3     1997      6     4          74           16  ...  0  0  0  0            0
# 4     1997      6     5          74           15  ...  0  0  0  0            0
# ...    ...    ...   ...         ...          ...  ... .. .. .. ..          ...
# 8375  2020      5     6          70            0  ...  0  0  0  0            0
# 8376  2020      5     7          69            0  ...  0  0  0  0            0
# 8377  2020      5     8          68            0  ...  0  0  0  0            0
# 8378  2020      5     9          71            0  ...  0  0  0  0            0
# 8379  2020      5    10          68            0  ...  0  0  0  0            0
#
# ...

# %% [markdown]
# class 0 = no flare |
# class 1 = c |
# class 2 = m |
# class 3 = x

# %%
X = dataset.iloc[1:, 0:38].values
y = dataset.iloc[1:,54].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)
#y_train = sc_y_train.fit_transform(y_train)
#y_test = sc_y_train.transform(X_test)

# %%
y_train=np.asarray(y_train,dtype=float)

# %%
# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = classifier.predict(X_test)
y_pred = np.asarray(y_pred,dtype=int)

# %%
y_test=np.asarray(y_test,dtype=int)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[711,  82,   0,   1],
#        [209, 367,  39,   0],
#        [ 41, 159,  39,   0],
#        [  3,  15,   8,   2]])

# %%
#for n=5  train:test = 8:2
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.90      0.81       794
#            1       0.59      0.60      0.59       615
#            2       0.45      0.16      0.24       239
#            3       0.67      0.07      0.13        28
#
#     accuracy                           0.67      1676
#    macro avg       0.61      0.43      0.44      1676
# weighted avg       0.64      0.67      0.64      1676

# %% [markdown]
# **Classification in optical class flares is not part of our project but it is done here only for demonstration purpose.**

# %% [markdown]
# #**Classifying all optical class flares using KNN**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_excel("Dataset_set_2_for_classification.xlsx")

# %%
dataset
# Out:
#         1      2     3           4   ... 53 54           55             56
# 0     YEAR  MONTH  DATE  RADIO FLUX  ...  3  4  x-ray class  optical class
# 1     1997      6     2          77  ...  0  0            0              0
# 2     1997      6     3          75  ...  0  0            0              0
# 3     1997      6     4          74  ...  0  0            0              0
# 4     1997      6     5          74  ...  0  0            0              0
# ...    ...    ...   ...         ...  ... .. ..          ...            ...
# 8375  2020      5     6          70  ...  0  0            0              0
# 8376  2020      5     7          69  ...  0  0            0              0
# 8377  2020      5     8          68  ...  0  0            0              0
# 8378  2020      5     9          71  ...  0  0            0              0
# 8379  2020      5    10          68  ...  0  0            0              0
#
# [8380 rows x 56 columns]

# %% [markdown]
# class 0 = no flare |
# class 1 = s |
# class 2 = one |
# class 3 = two |
# class 4 = three |
# class 5 = four |

# %%
X = dataset.iloc[1:, 0:38].values
y = dataset.iloc[1:,55].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.5, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)
#y_train = sc_y_train.fit_transform(y_train)
#y_test = sc_y_train.transform(X_test)

# %%
y_train=np.asarray(y_train,dtype=float)

# %%
# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
y_pred = classifier.predict(X_test)
y_pred = np.asarray(y_pred,dtype=int)

# %%
y_test=np.asarray(y_test,dtype=int)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1686,  274,   11,    1,    0,    0],
#        [ 578,  809,  127,   10,    1,    0],
#        [  87,  336,   80,    8,    1,    0],
#        [  25,   98,   33,    5,    0,    0],
#        [   3,    9,    4,    2,    0,    0],
#        [   1,    0,    1,    0,    0,    0]])

# %%
#for n=5  train:test = 8:2
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.78       781
#            1       0.55      0.57      0.56       602
#            2       0.45      0.21      0.29       218
#            3       0.40      0.03      0.06        63
#            4       0.00      0.00      0.00        11
#            5       0.00      0.00      0.00         1
#
#     accuracy                           0.63      1676
#    macro avg       0.35      0.28      0.28      1676
# weighted avg       0.60      0.63      0.60      1676
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#for n=5  train:test = 7:3
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77      1178
#            1       0.53      0.55      0.54       905
#            2       0.39      0.17      0.24       316
#            3       0.44      0.04      0.07       100
#            4       0.00      0.00      0.00        14
#            5       0.00      0.00      0.00         1
#
#     accuracy                           0.62      2514
#    macro avg       0.35      0.27      0.27      2514
# weighted avg       0.59      0.62      0.59      2514
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#for n=5  train:test = 6:4
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.76      1571
#            1       0.53      0.55      0.54      1217
#            2       0.34      0.16      0.22       410
#            3       0.31      0.03      0.05       134
#            4       0.00      0.00      0.00        18
#            5       0.00      0.00      0.00         2
#
#     accuracy                           0.61      3352
#    macro avg       0.31      0.26      0.26      3352
# weighted avg       0.57      0.61      0.58      3352
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#for n=5  train:test = 5:5
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.85      0.77      1972
#            1       0.53      0.53      0.53      1525
#            2       0.31      0.16      0.21       512
#            3       0.19      0.03      0.05       161
#            4       0.00      0.00      0.00        18
#            5       0.00      0.00      0.00         2
#
#     accuracy                           0.62      4190
#    macro avg       0.29      0.26      0.26      4190
# weighted avg       0.57      0.62      0.59      4190
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
