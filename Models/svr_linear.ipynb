# %% [markdown]
# #**SVR (Linear kernel)**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_excel("Dataset_set_2.xlsx")

# %% [markdown]
# #**C-class Flares**

# %%
X = dataset.iloc[1:, 0:38].values
y = dataset.iloc[1:, 38].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = regressor.predict(X_test)
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
for i in range(0,len(y_pred)):
  if y_pred[i]>=1:
    y_pred[i]=1
  else:
    y_pred[i]=0
  if y_test[i]>=1:
    y_test[i]=1
  else:
    y_test[i]=0

# %%
from sklearn.metrics import confusion_matrix
cm_1 = confusion_matrix(y_test, y_pred)
cm_1
# Out:
# array([[1354,  296],
#        [ 201, 1501]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      1650
#            1       0.84      0.88      0.86      1702
#
#     accuracy                           0.85      3352
#    macro avg       0.85      0.85      0.85      3352
# weighted avg       0.85      0.85      0.85      3352

# %% [markdown]
# #**M-class Flares**

# %% [markdown]
# Without using C-class flares data

# %%
X = dataset.iloc[1:, 0:38].values
y = dataset.iloc[1:, 39].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = regressor.predict(X_test)
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
for i in range(0,len(y_pred)):
  if y_pred[i]>=1:
    y_pred[i]=1
  else:
    y_pred[i]=0
  if y_test[i]>=1:
    y_test[i]=1
  else:
    y_test[i]=0

# %%
from sklearn.metrics import confusion_matrix
cm_1 = confusion_matrix(y_test, y_pred)
cm_1
# Out:
# array([[2848,   10],
#        [ 462,   32]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      2858
#            1       0.76      0.06      0.12       494
#
#     accuracy                           0.86      3352
#    macro avg       0.81      0.53      0.52      3352
# weighted avg       0.85      0.86      0.80      3352

# %% [markdown]
# Using C-class flares data

# %%
X = dataset.iloc[1:, 0:39].values
y = dataset.iloc[1:, 39].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = regressor.predict(X_test)
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
for i in range(0,len(y_pred)):
  if y_pred[i]>=1:
    y_pred[i]=1
  else:
    y_pred[i]=0
  if y_test[i]>=1:
    y_test[i]=1
  else:
    y_test[i]=0

# %%
from sklearn.metrics import confusion_matrix
cm_1 = confusion_matrix(y_test, y_pred)
cm_1
# Out:
# array([[2848,   10],
#        [ 466,   28]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92      2858
#            1       0.74      0.06      0.11       494
#
#     accuracy                           0.86      3352
#    macro avg       0.80      0.53      0.51      3352
# weighted avg       0.84      0.86      0.80      3352

# %% [markdown]
# #**X-class flares**

# %% [markdown]
# Without using C-class and M-class flares data

# %%
X = dataset.iloc[1:, 0:38].values
y = dataset.iloc[1:, 40].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = regressor.predict(X_test)

# %%
for i in range(0,len(y_pred)):
  if y_pred[i]>=0.5:          #threshold value for y_pred is decreased to 0.5
    y_pred[i]=1
  else:
    y_pred[i]=0
  if y_test[i]>=1:
    y_test[i]=1
  else:
    y_test[i]=0

# %%
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
from sklearn.metrics import confusion_matrix
cm_1 = confusion_matrix(y_test, y_pred)
cm_1
# Out:
# array([[1648,    0],
#        [  28,    0]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1648
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.98      1676
#    macro avg       0.49      0.50      0.50      1676
# weighted avg       0.97      0.98      0.98      1676
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Using C-class flares data

# %%
X = dataset.iloc[1:, 0:39].values
y = dataset.iloc[1:, 40].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0) #Changing the train:test to 80:20

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = regressor.predict(X_test)
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
for i in range(0,len(y_pred)):
  if y_pred[i]>=0.5:              #threshold value for y_pred is decreased to 0.5
    y_pred[i]=1
  else:
    y_pred[i]=0
  if y_test[i]>=1:
    y_test[i]=1
  else:
    y_test[i]=0

# %%
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
from sklearn.metrics import confusion_matrix
cm_1 = confusion_matrix(y_test, y_pred)
cm_1
# Out:
# array([[1648,    0],
#        [  28,    0]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1648
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.98      1676
#    macro avg       0.49      0.50      0.50      1676
# weighted avg       0.97      0.98      0.98      1676
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Using C-class and M-class flares data

# %%
X = dataset.iloc[1:, 0:40].values
y = dataset.iloc[1:, 40].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)#Changing the train:test to 80:20

# %%
from sklearn.preprocessing import StandardScaler
sc_X_train = StandardScaler()
sc_y_train = StandardScaler()
X_train = sc_X_train.fit_transform(X_train)
X_test = sc_X_train.transform(X_test)

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'linear')
regressor.fit(X_train, y_train)
# Out:
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='linear', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
y_pred = regressor.predict(X_test)
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
for i in range(0,len(y_pred)):
  if y_pred[i]>=0.5:              #threshold value for y_pred is decreased to 0.5
    y_pred[i]=1
  else:
    y_pred[i]=0
  if y_test[i]>=1:
    y_test[i]=1
  else:
    y_test[i]=0

# %%
y_test=np.asarray(y_test,dtype=int)
y_pred=np.asarray(y_pred,dtype=int)

# %%
from sklearn.metrics import confusion_matrix
cm_1 = confusion_matrix(y_test, y_pred)
cm_1
# Out:
# array([[1648,    0],
#        [  28,    0]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1648
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.98      1676
#    macro avg       0.49      0.50      0.50      1676
# weighted avg       0.97      0.98      0.98      1676
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
